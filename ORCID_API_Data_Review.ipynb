# %%
## Dependencies
import requests
from requests.exceptions import HTTPError
import json
from config import ClientID
from config import Clientsecret
from urllib.parse import urlencode
from pandas.io.json import json_normalize  
import pandas as pd

import sys, os
import re
import glob
import numpy as np
from pprint import pprint



## ORCID (orcid-python) package is outdated
## https://github.com/scholrly/orcid-python
## pip list -v can be used to list packages' install locations
## C:\Users\keg827\AppData\Local\Continuum\anaconda3\Lib\site-packages

## Take a look at Python 3.0 Wiki Built-in Changes section, where it is stated:
## Removed dict.iteritems(), dict.iterkeys(), and dict.itervalues().
## Instead: use dict.items(), dict.keys(), and dict.values() respectively.

# import orcid
# from inspect import getmembers, isfunction
# print(getmembers(orcid, isfunction))
# help(orcid)

## Python-Orcid package also does not work: 
## https://github.com/ORCID/python-orcid

# %% [markdown]
# ## Pathway for reading data from ORCID Member API
#
# In this pathway you will use the /read-public endpoint. Do not confuse this with the /read-limited endpoint, as that endpoint is meant for reading data from a specific user record and requires the 3-leg authentication (i.e. exchanging the code for the user's token) where the user must authenticate which gives you (or your web app) permission to read the data.
#
# The /read-public end point is sufficient if you want to search and return data from the ORCID database from your university, for example.

# %%
## Step 1: Use the /oath/token endpoint to receive the token needed for using the /read-pubic endpoint

## Set up header and parameters for post request

headers = {
    "accept": "application/json",
    "method": "post"
}

data = {
    "client_id": ClientID,
    "client_secret": Clientsecret,
    "grant_type" : "client_credentials",
    "scope": "/read-public"
}


## Create try/catch loop for request

## production API = https://api.orcid.org
## sandbox API = https://sandbox.orcid.org/oauth/toke

for url in ["https://sandbox.orcid.org/oauth/token"]:
    try: 
        ## Make the API post request 
        response = requests.post(url, headers = headers, data = data) 
        
        ## Print responses
        print(response.status_code)
        print(response.url)
        print(response.text)
        print(type(response.text))
        response_string = response.text
        
        ## If the response was successful, no Exception will be raised
        response.raise_for_status()
    
    except HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')  # Python 3.6
   
    except Exception as err:
        print(f'Other error occurred: {err}')  # Python 3.6
    
    else:
        print('Success!')
        

## Resources
## https://info.orcid.org/documentation/api-tutorials/api-tutorial-read-data-on-a-record/#easy-faq-2536

# %%
 ## Step 2: Use the access token and call the /read-public endpoint

## Save the token as a variable
json_token = json.loads(response_string)
print(json_token["access_token"])
final_token = json_token["access_token"]


## Save the query items as variables
ringgold_id = "3270" 
grid_id = "grid.16753.36" 
email_domain = "@northwestern.edu" 
organization_name = "Northwestern University"
organization_name2 = "Northwestern"

## Save the items in a list that you'd like returned

# fieldList = ["orcid", "email", "given-name","family-name", "given-and-family-names", "credit-name",
#              "other-name","current-institution-affiliation-name","past-institution-affiliation-name"]


## Set up query for request

query_dict = {
     "ringgold-org-id":ringgold_id,
     "OR grid-org-id":grid_id, 
     "OR email": email_domain,
     "OR affiliation-org-name": organization_name,
     "affiliation-org-name": organization_name2
}

query_str = urlencode(query_dict)
#print(query_str)

#search_url = f"https://api.sandbox.orcid.org/v3.0/expanded-search/?q={query_str}" 

## production API = https://api.orcid.org
## sandbox API = https://sandbox.orcid.org/oauth/toke
#print(search_url)

## Set up headers and parameters for request

headers = {
    "Accept": "application/json",
    "Authorization": f'Bearer{final_token}' 
}


# parameters = {
#     #"access_token": final_token,
#    # "q" : query_str,
#     "field": ",".join(fieldList)
    
# }

#search_url = "https://api.sandbox.orcid.org/search/?"

search_response_list = []

def get_request(query_str, headers, search_response_list):
    
    #search_response_list = []
    start = 0
    rows = 1000

    while True: 
        
        try:
                
                ## Create URL for request
                print("------")
                search_url = f"https://api.sandbox.orcid.org/v3.0/expanded-search/?q={query_str}&start={start}&rows={rows}" 
                print("Requesting", search_url)
                
                ## Make the API post request 
                search_response = requests.get(search_url, headers = headers,  timeout=30) # params = parameters,
                #print(type(search_response))
                json_data = search_response.json()
                #print(json_data["expanded-result"][0]["orcid-id"])
                #print(type(json_data))
                
                ## Print responses
                print("Search Status", search_response.status_code)
                # print(search_response.url)
                # print(search_response.text)
                # print(type(search_response.text))
                
                
                ## If the response was successful, no Exception will be raised
                search_response.raise_for_status()
                
                ## Need something that will give us an error, or else it will keep working
                print(json_data["expanded-result"][0]["orcid-id"]) 
                
               
               
                ## If we did find more ORCID data, add them to the list and move on to next offset
                search_response_list.extend(json_data["expanded-result"])
                
                
                
        except HTTPError as http_err:
                print(f'HTTP error occurred: {http_err}')  # Python 3.6
                break

        except Exception as err:
                print(f'Other error occurred: {err}')  # Python 3.6
                print(search_response.url)
                break

        else:
                print('Success!')
        
        start = start + 1000

    return search_response_list


get_request(query_str, headers, search_response_list)

print(len(search_response_list))
print(type(search_response_list))

## Notes
## Please note the Public API is limited to 10,000 results. 
## Using the Member API (with a Member API token) does not limit the number of results.

## Resources
## https://info.orcid.org/faq/how-do-i-find-orcid-record-holders-at-my-institution/
## https://info.orcid.org/documentation/api-tutorials/api-tutorial-read-data-on-a-record/#easy-faq-2361
## https://info.orcid.org/documentation/api-tutorials/api-tutorial-searching-the-orcid-registry/
## https://realpython.com/python-api/#request-and-response
## http://www.compciv.org/guides/python/how-tos/creating-proper-url-query-strings/
## https://stackoverflow.com/questions/17788445/constructing-requests-with-url-query-string-in-python
## Using paginated APIs (4 ways): https://www.youtube.com/watch?v=4Fdyft-ky0w
# Out:
# f3e2ef7f-0d36-4bc6-b4aa-64fd59f0a75d
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=0&rows=1000
# Search Status 200
# 0000-0002-0564-3270
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=1000&rows=1000
# Search Status 200
# 0000-0002-4672-494X
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=2000&rows=1000
# Search Status 200
# 0000-0002-9257-0304
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=3000&rows=1000
# Search Status 200
# 0000-0002-9374-2411
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=4000&rows=1000
# Search Status 200
# 0000-0002-8967-4356
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=5000&rows=1000
# Search Status 200
# 0000-0003-0732-1213
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=6000&rows=1000
# Search Status 200
# 0000-0003-4000-3620
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=7000&rows=1000
# Search Status 200
# 0000-0002-2142-5089
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=8000&rows=1000
# Search Status 200
# 0000-0002-0377-4517
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=9000&rows=1000
# Search Status 200
# 0000-0003-4235-0191
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=10000&rows=1000
# Search Status 200
# 0000-0001-5107-4825
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=11000&rows=1000
# Search Status 200
# 0000-0003-3348-223X
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=12000&rows=1000
# Search Status 200
# 0000-0002-8405-297X
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=13000&rows=1000
# Search Status 200
# 0000-0003-3224-5478
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=14000&rows=1000
# Search Status 200
# 0000-0002-0074-3918
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=15000&rows=1000
# Search Status 200
# 0000-0003-2442-5807
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=16000&rows=1000
# Search Status 200
# 0000-0003-3348-3435
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=17000&rows=1000
# Search Status 200
# 0000-0003-4443-0849
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=18000&rows=1000
# Search Status 200
# 0000-0001-7723-4743
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=19000&rows=1000
# Search Status 200
# 0000-0001-8806-8744
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=20000&rows=1000
# Search Status 200
# 0000-0003-0828-1452
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=21000&rows=1000
# Search Status 200
# 0000-0002-5073-6345
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=22000&rows=1000
# Search Status 200
# 0000-0002-6810-6157
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=23000&rows=1000
# Search Status 200
# 0000-0002-3935-6157
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=24000&rows=1000
# Search Status 200
# 0000-0002-5973-8750
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=25000&rows=1000
# Search Status 200
# 0000-0002-8603-0678
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=26000&rows=1000
# Search Status 200
# 0000-0003-2042-572X
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=27000&rows=1000
# Search Status 200
# 0000-0001-5716-0302
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=28000&rows=1000
# Search Status 200
# 0000-0001-5852-7401
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=29000&rows=1000
# Search Status 200
# 0000-0001-6287-051X
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=30000&rows=1000
# Search Status 200
# 0000-0003-1771-8126
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=31000&rows=1000
# Search Status 200
# 0000-0001-6970-1524
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=32000&rows=1000
# Search Status 200
# 0000-0003-2973-5732
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=33000&rows=1000
# Search Status 200
# 0000-0002-1762-3584
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=34000&rows=1000
# Search Status 200
# 0000-0002-5074-525X
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=35000&rows=1000
# Search Status 200
# 0000-0003-4228-7700
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=36000&rows=1000
# Search Status 200
# 0000-0001-6929-8536
# Success!
# ------
# Requesting https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=37000&rows=1000
# Search Status 200
# Other error occurred: 'NoneType' object is not subscriptable
# https://api.sandbox.orcid.org/v3.0/expanded-search/?q=ringgold-org-id=3270&OR+grid-org-id=grid.16753.36&OR+email=%40northwestern.edu&OR+affiliation-org-name=Northwestern+University&affiliation-org-name=Northwestern&start=37000&rows=1000
# [{'orcid-id': '0000-0002-0564-3270',
#   'given-names': 'ALIREZA',
#   'family-names': 'DOOSTAN',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-3270-2838',
#   'given-names': 'Priya',
#   'family-names': 'Joshi',
#   'credit-name': None,
#   'other-name': [],
#   'email': ['priya.joshi454@bmc.org', 'pjoshi454@bu.edu'],
#   'institution-name': []},
#  {'orcid-id': '0000-0001-9962-7513',
#   'given-names': 'Researcher',
#   'family-names': 'Test',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Mc Gill University',
#    'My College',
#    'My University',
#    'The Place to Study',
#    'University ABCD',
#    'University EFGH']},
#  {'orcid-id': '0000-0002-3270-5131',
#   'given-names': 'Carl',
#   'family-names': "O'Hara",
#   'credit-name': None,
#   'other-name': [],
#   'email': ['hara461@bu.edu'],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-3270-2950',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-4530-3270',
#   'given-names': 'Christopher',
#   'family-names': 'Kellen',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0001-6725-3270',
#   'given-names': 'Andrew',
#   'family-names': 'Davies',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0003-3365-3270',
#   'given-names': 'Thomais',
#   'family-names': 'Mertzanidou',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0003-2653-3270',
#   'given-names': 'Alan',
#   'family-names': 'Ladd',
#   'credit-name': 'Alan Ladd',
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0003-2629-3270',
#   'given-names': 'Josiah',
#   'family-names': 'Carberry',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0003-3200-4420',
#   'given-names': None,
#   'family-names': None,
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['A',
#    'AAA',
#    'AAAA',
#    'AAAAA',
#    'AB',
#    'B',
#    'CCCCC',
#    'EA',
#    'F',
#    'Org',
#    'Pending A',
#    'Tasty',
#    'Test',
#    'aaa',
#    'aaaaBCD',
#    'addd',
#    'atest',
#    'test']},
#  {'orcid-id': '0000-0002-3916-5094',
#   'given-names': 'Camelia',
#   'family-names': 'Testcami',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['NASA',
#    'ORCID Inc',
#    'ORCID2',
#    'University of Wisconsin-Madison']},
#  {'orcid-id': '0000-0002-2099-3156',
#   'given-names': 'Anju',
#   'family-names': 'Test',
#   'credit-name': None,
#   'other-name': [],
#   'email': ['hello2@mailinator.com', 'hello@mailinator.com'],
#   'institution-name': ['Dana Farber Cancer Institute',
#    'Northwestern University',
#    'University of Pennsylvania']},
#  {'orcid-id': '0000-0003-0233-7734',
#   'given-names': 'Pradeep',
#   'family-names': 'chand',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Lockheed Martin Information Systems and Global Services Rockville',
#    'Texas A&M International University']},
#  {'orcid-id': '0000-0003-3270-8946',
#   'given-names': 'Nicholas',
#   'family-names': 'Sheppard',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Life']},
#  {'orcid-id': '0000-0002-3270-0584',
#   'given-names': 'Swecog',
#   'family-names': 'Memberson',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0003-3270-8022',
#   'given-names': 'Louise',
#   'family-names': 'Nightingale',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-9964-3270',
#   'given-names': 'Dilufar',
#   'family-names': 'Xodjaeva',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-9200-3270',
#   'given-names': 'super',
#   'family-names': 'weird',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-0743-9185',
#   'given-names': 'Henrik',
#   'family-names': 'Kragh-Hansen',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Org']},
#  {'orcid-id': '0000-0001-7755-9097',
#   'given-names': 'Bingbing',
#   'family-names': 'Hu',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Hong Kong Baptist University']},
#  {'orcid-id': '0000-0001-6220-0401',
#   'given-names': 'Daniel',
#   'family-names': 'Palafox',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['ORCID',
#    'ORCID: Bethesda',
#    'University of Wisconsin-Madison',
#    'caca',
#    'dsadsadsdas']},
#  {'orcid-id': '0000-0003-4438-0378',
#   'given-names': 'Alfred',
#   'family-names': 'Newman',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['John C. Fry Landscaping',
#    'Northwestern University',
#    'White Pigeon High School']},
#  {'orcid-id': '0000-0003-3915-6224',
#   'given-names': 'Amneh',
#   'family-names': 'AbuRub',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Al Balqa Applied University',
#    'aixprocess GmbH',
#    'global Institut für Sprachen und Kommunikation',
#    'medico international ev',
#    'org']},
#  {'orcid-id': '0000-0001-9383-9240',
#   'given-names': 'Tuesday',
#   'family-names': '18Aug2020-2',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Wisconsin-Madison']},
#  {'orcid-id': '0000-0001-5080-9957',
#   'given-names': 'Tuesday',
#   'family-names': '18Aug2020-3',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Wisconsin-Madison']},
#  {'orcid-id': '0000-0002-4979-0213',
#   'given-names': 'Shron',
#   'family-names': 'Chair',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Employers Dental Services Inc',
#    'Massachusetts Institute of Technology',
#    'Royal College of Physicians',
#    'org']},
#  {'orcid-id': '0000-0001-6559-6245',
#   'given-names': "Doa'a",
#   'family-names': 'Darwish',
#   'credit-name': None,
#   'other-name': ["Doa'a Ahmad", 'Do3a2'],
#   'email': [],
#   'institution-name': ["Doaa's Org",
#    'Javna',
#    'Jordan Hospital',
#    'Ringold',
#    'qualification']},
#  {'orcid-id': '0000-0002-7688-2623',
#   'given-names': 'Record with org 1',
#   'family-names': None,
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['1984 ehf']},
#  {'orcid-id': '0000-0002-0792-7189',
#   'given-names': "Da'Ron",
#   'family-names': 'McMiller',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['American Red Cross',
#    'George Mason University',
#    'Old Dominion University',
#    'Test org',
#    'University of Notre Dame',
#    'VCU Life Sciences']},
#  {'orcid-id': '0000-0002-6553-1561',
#   'given-names': 'Neat Paladin',
#   'family-names': None,
#   'credit-name': 'Tommy Winther',
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Org']},
#  {'orcid-id': '0000-0001-8228-7153',
#   'given-names': 'rosh',
#   'family-names': 'pawar',
#   'credit-name': None,
#   'other-name': ['dummy 1220',
#    'dummy 10',
#    'dummy 1220sdhfdj',
#    'dummy 1220s',
#    'dummy 1220spp45'],
#   'email': [],
#   'institution-name': ['ORG 123',
#    'PRODATA',
#    'QPIC Consultants Sdn Bhd',
#    'SSCG Media Group LLC',
#    'SSE Renewables Holdings Ltd',
#    'The University of Auckland',
#    'University of Texas Medical School at San Antonio',
#    'University of Wisconsin Madison']},
#  {'orcid-id': '0000-0003-2889-7035',
#   'given-names': 'Ana',
#   'family-names': 'Almada',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Campus Universitário de Almada',
#    'Instituto Superior de Estudos Interculturais e Transdisciplinares de Almada',
#    'McGill University']},
#  {'orcid-id': '0000-0002-6981-3312',
#   'given-names': 'Donna',
#   'family-names': 'Alvior BCM',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Baylor College of Medicine',
#    'Coolest Person Organization',
#    'Some Org',
#    'University of Houston']},
#  {'orcid-id': '0000-0002-3714-8813',
#   'given-names': 'Ben',
#   'family-names': 'Hand',
#   'credit-name': 'Amazing',
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Aalborg Universitet',
#    'An Official Organization',
#    'BASF (Germany)',
#    'Kanazawa University',
#    'PowerSchool Academy',
#    'Sunyani Polytechnic',
#    'The Institute',
#    'University of Granada',
#    'University of Las Palmas de Gran Canaria',
#    'adsfasd',
#    'another one',
#    'asdfsadf',
#    'asdfttewer',
#    'org name is awesome']},
#  {'orcid-id': '0000-0002-3791-8427',
#   'given-names': 'Soon',
#   'family-names': 'Chang',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Massachusetts Institute of Technology',
#    'National University of Singapore',
#    'Peking University',
#    'Shanghai Jiao Tong University']},
#  {'orcid-id': '0000-0002-5152-8900',
#   'given-names': 'fredy prueba 3',
#   'family-names': None,
#   'credit-name': None,
#   'other-name': ['Apodo'],
#   'email': [],
#   'institution-name': ['Org Olbitagorio',
#    'Organización nombre',
#    'Qualification name',
#    'Town of Harvard',
#    'Universidad Continental',
#    'education nombre',
#    'invited position',
#    'menbership organization',
#    'organizacion',
#    'service organization']},
#  {'orcid-id': '0000-0002-1113-2813',
#   'given-names': 'Per',
#   'family-names': 'Jensen',
#   'credit-name': 'Per Jensen',
#   'other-name': [],
#   'email': [],
#   'institution-name': ['PAJs org']},
#  {'orcid-id': '0000-0002-8360-2765',
#   'given-names': 'Tuesday',
#   'family-names': '18Aug2020',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['university of wisconsin']},
#  {'orcid-id': '0000-0001-8613-0145',
#   'given-names': 'Paula',
#   'family-names': 'Demain',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['John Wiley and Sons']},
#  {'orcid-id': '0000-0002-7104-0574',
#   'given-names': 'Friday',
#   'family-names': '27Aug2020',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Wisconsin-Madison']},
#  {'orcid-id': '0000-0003-1364-0544',
#   'given-names': 'Wednesday',
#   'family-names': '05Aug2020',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Wisconsin-Madison']},
#  {'orcid-id': '0000-0002-0667-786X',
#   'given-names': 'Researcher04',
#   'family-names': 'Researcher04',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Wisconsin-Madison']},
#  {'orcid-id': '0000-0001-5898-1022',
#   'given-names': 'Monday',
#   'family-names': '28Oct2020',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Wisconsin-Madison']},
#  {'orcid-id': '0000-0002-8913-4253',
#   'given-names': 'Søren',
#   'family-names': 'Andersen',
#   'credit-name': 'Søren Andersen',
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Root Org']},
#  {'orcid-id': '0000-0003-4230-1322',
#   'given-names': 'Wendy',
#   'family-names': 'Kuohung',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Boston University School of Medicine']},
#  {'orcid-id': '0000-0003-2302-9052',
#   'given-names': 'Testing',
#   'family-names': 'Funding',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0003-0019-9251',
#   'given-names': 'Some',
#   'family-names': 'Guy',
#   'credit-name': None,
#   'other-name': ['Bob'],
#   'email': [],
#   'institution-name': ['X Org']},
#  {'orcid-id': '0000-0001-9173-0559',
#   'given-names': 'org',
#   'family-names': 'org111',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0003-3115-2827',
#   'given-names': 'org',
#   'family-names': 'org999',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-6886-1638',
#   'given-names': 'Given',
#   'family-names': 'Family',
#   'credit-name': 'Unclaimed record',
#   'other-name': ['AKA', '1234'],
#   'email': ['c.oyler+mar20@orcid.org'],
#   'institution-name': []},
#  {'orcid-id': '0000-0003-0774-2034',
#   'given-names': 'Given',
#   'family-names': 'Family',
#   'credit-name': 'Unclaimed record',
#   'other-name': ['AKA', '1234'],
#   'email': ['c.oyler+mar20s@orcid.org'],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-7723-4310',
#   'given-names': 'Christian Albrekt',
#   'family-names': 'Larsen',
#   'credit-name': 'Christian Albrekt Larsen',
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Root Org']},
#  {'orcid-id': '0000-0002-8465-2297',
#   'given-names': 'Given',
#   'family-names': 'Family',
#   'credit-name': 'Unclaimed record',
#   'other-name': ['AKA', '1234'],
#   'email': ['c.oyler+jan5d@orcid.org'],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-3431-6674',
#   'given-names': 'Given',
#   'family-names': 'Family',
#   'credit-name': 'Unclaimed record',
#   'other-name': ['AKA', '1234'],
#   'email': ['c.oyler+mar14a@orcid.org'],
#   'institution-name': []},
#  {'orcid-id': '0000-0001-7628-5135',
#   'given-names': 'Given',
#   'family-names': 'Family',
#   'credit-name': 'Uncalimed Support record',
#   'other-name': ['AKA', '1234'],
#   'email': ['c.oyler+jun28@orcid.org'],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-7669-9044',
#   'given-names': 'Stephan',
#   'family-names': 'Schwaer',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Albert-Ludwigs-Universität Freiburg',
#    'TU-Darmstadt',
#    'Technical University Darmstadt',
#    'org name']},
#  {'orcid-id': '0000-0002-0337-6957',
#   'given-names': 'Gabriel',
#   'family-names': 'Bucco',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Test',
#    'Test Education',
#    'Test Org',
#    'Test Qualification']},
#  {'orcid-id': '0000-0001-7091-4420',
#   'given-names': None,
#   'family-names': None,
#   'credit-name': 'Org 2 Consortium Member',
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-1176-4597',
#   'given-names': None,
#   'family-names': None,
#   'credit-name': 'Org 3 Consortium Member',
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-6806-2078',
#   'given-names': 'TestFran',
#   'family-names': 'Researcher',
#   'credit-name': None,
#   'other-name': ['SB-Tester', 'Other Name'],
#   'email': [],
#   'institution-name': ['Distinction for being nice',
#    'IRCCS Humanitas Research Hospital',
#    'Invited Position',
#    'ORGANIZATION NAME',
#    'Service Organization',
#    'common:name']},
#  {'orcid-id': '0000-0002-7603-9492',
#   'given-names': 'Given',
#   'family-names': 'Family',
#   'credit-name': 'Credit Name',
#   'other-name': ['added with V2', 'added in old inerface', 'AKA', '1234'],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0003-1892-8352',
#   'given-names': 'abedalrahman',
#   'family-names': 'nabeel',
#   'credit-name': None,
#   'other-name': ['abed',
#    'koko',
#    'pr abed',
#    'eng abed',
#    'dr abed',
#    'Abed From Joip Name',
#    'Abu Omar',
#    'abood',
#    'aboood1',
#    'Test 123',
#    'kokok',
#    'asdasdasd',
#    'abod',
#    'asdsadqweqwe',
#    'abdnabeel',
#    'Test 2 edit',
#    'Abed Nabeel Foqaha',
#    'abu omar foqaha',
#    'abu omar ab',
#    'abood3',
#    'after deploy schedual'],
#   'email': ['anabeel@mailinator.com',
#    'anabeel@javna.com',
#    'abed.nabeel1@hotmail.com',
#    'abed.nabeel@gmail1.com',
#    'abed.nabeel2@gmail.com'],
#   'institution-name': ['CrossRef',
#    'GRID',
#    'Javna Biblioteka Zavidovići',
#    'Jordan Hospital',
#    'LEI ORG',
#    'Ringgold',
#    'Ringold',
#    'The University of Jordan Deanship of Academic Research',
#    'United Air Lines Inc',
#    'asdqweqwe',
#    'distionciton',
#    'javna Jordan',
#    'jim',
#    'service']},
#  {'orcid-id': '0000-0002-2324-1910',
#   'given-names': 'pc',
#   'family-names': None,
#   'credit-name': None,
#   'other-name': [],
#   'email': ['pcpersonorcid@mailinator.com', 'pcpersonorcid1@mailinator.com'],
#   'institution-name': ['New Edubiase Secondary School',
#    'Opcina Tesanj',
#    'Org 1',
#    'University of Bristol']},
#  {'orcid-id': '0000-0002-8527-1541',
#   'given-names': 'wiv200',
#   'family-names': 'Lo',
#   'credit-name': 'wiv200lo',
#   'other-name': ['wivwiv', 'hellow', 'appwv'],
#   'email': ['wivina.lo@gmail.com', 'wiv200@mailinator.com'],
#   'institution-name': ['Aberystwyth University',
#    'Birmingham City University',
#    'Esys (United Kingdom)',
#    'Kalamazoo Valley Community College',
#    'NASA Goddard Space Flight Center',
#    'New York University',
#    'Oracle UK',
#    'RMIT University - Point Cook Campus',
#    'Shirak Marz Center Gyumri',
#    'Snelling-Merced Falls Union School District',
#    'Universidad Carlos III de Madrid',
#    'University of Cambridge',
#    'University of Oxford',
#    'University of Toronto']},
#  {'orcid-id': '0000-0002-3941-4353',
#   'given-names': 'Given',
#   'family-names': 'Family',
#   'credit-name': 'API record',
#   'other-name': ['AKA', '1234'],
#   'email': ['c.oyler+jun13@orcid.org'],
#   'institution-name': []},
#  {'orcid-id': '0000-0003-0806-0393',
#   'given-names': 'Marwan',
#   'family-names': 'Kutkut',
#   'credit-name': None,
#   'other-name': [],
#   'email': ['marleenhaddad@mailinator.com'],
#   'institution-name': ['Jordan University of Science and Technology',
#    'Microsoft Corp',
#    'New VA Org',
#    'ORCID',
#    'ORCID - Education',
#    'ORCID - Membership',
#    'ORCID - Service',
#    'ORCID -Education',
#    'ORCID-Qualifaction',
#    'Ohio University',
#    'TEST',
#    'Test from ORCID',
#    'UCD Institute of Criminology',
#    'University College Dublin',
#    'VIDATUM - Membership',
#    'test for Saadi',
#    'value 02']},
#  {'orcid-id': '0000-0002-1765-0478',
#   'given-names': 'Claiming',
#   'family-names': 'Test',
#   'credit-name': None,
#   'other-name': ['Test'],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0001-8445-1084',
#   'given-names': 'Eamil',
#   'family-names': 'Test',
#   'credit-name': None,
#   'other-name': ['Test'],
#   'email': ['c.oyler+unc@orcid.org'],
#   'institution-name': []},
#  {'orcid-id': '0000-0001-9265-5933',
#   'given-names': '木子',
#   'family-names': '李',
#   'credit-name': '李木子',
#   'other-name': ['Li Muzi',
#    'Muzi Li',
#    'Li M Z',
#    'M Z Li',
#    'Li MZ',
#    'MZ Li',
#    'Li M.Z.',
#    'M.Z. Li',
#    'Li, MZ',
#    'Li, M.Z.'],
#   'email': ['iauthor001@163.com'],
#   'institution-name': ['abcd', '中国科学院文献情报中心', '中国科学院高能物理研究所']},
#  {'orcid-id': '0000-0003-4792-5310',
#   'given-names': 'Yuxian',
#   'family-names': 'Wang',
#   'credit-name': None,
#   'other-name': ['Chily Wang'],
#   'email': ['xiaoleixia1994@163.com'],
#   'institution-name': ['Chinese Academy of Geological Sciences',
#    'Chinese Academy of History',
#    'Chinese Academy of Sciences',
#    'Chongqing Academy of Chinese Materia Medica',
#    'Givaudan Fragrances Shanghai Ltd Shanghai',
#    'National Space Science Center Chinese Academy of Sciences',
#    'Shandong University at Weihai',
#    'Shenyang Institute of Automation Chinese Academy of Sciences',
#    'University of Hong Kong',
#    'cPacket (United States)',
#    'coIMMUNE']},
#  {'orcid-id': '0000-0002-0212-9233',
#   'given-names': 'Robert',
#   'family-names': 'Sanderson',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Northwestern University']},
#  {'orcid-id': '0000-0001-5664-5842',
#   'given-names': 'Sandbox',
#   'family-names': 'test',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0003-3374-579X',
#   'given-names': 'lina',
#   'family-names': 'patel',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0003-4516-2372',
#   'given-names': 'TEST',
#   'family-names': 'TEST2',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-2679-6479',
#   'given-names': 'Yasmeen',
#   'family-names': 'Alsaedi',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['King Abdullah University of Science and Technology (KAUST)',
#    'Test name']},
#  {'orcid-id': '0000-0002-3588-6521',
#   'given-names': 'Jeanne',
#   'family-names': 'Horvath',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Michigan']},
#  {'orcid-id': '0000-0002-3008-0422',
#   'given-names': 'Daniel',
#   'family-names': 'Jimenez',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['The University of Auckland']},
#  {'orcid-id': '0000-0003-3824-0467',
#   'given-names': 'Radomirs',
#   'family-names': 'Cirskis',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['The University of Auckland',
#    'The university of auckland']},
#  {'orcid-id': '0000-0003-0318-3984',
#   'given-names': 'Radomirs',
#   'family-names': 'Cirskis',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Royal Org1',
#    'Royal Society Te Apārangi',
#    'Royal Society of New Zealand',
#    'TEST001',
#    'Test Education Ltd',
#    'Test Innovations',
#    'string']},
#  {'orcid-id': '0000-0003-4653-3702',
#   'given-names': 'AUTH',
#   'family-names': None,
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Aristotle University of Thessaloniki']},
#  {'orcid-id': '0000-0003-2221-3288',
#   'given-names': 'jeff',
#   'family-names': 'kennedy',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['The University of Auckland']},
#  {'orcid-id': '0000-0003-4018-5786',
#   'given-names': 'final',
#   'family-names': 'account',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['full stop',
#    'grid ID',
#    'ringgold test ID',
#    'write into ORCID',
#    'write to ORCID']},
#  {'orcid-id': '0000-0002-5925-6081',
#   'given-names': 'Penn',
#   'family-names': 'Team',
#   'credit-name': None,
#   'other-name': ['Tester'],
#   'email': [],
#   'institution-name': ['test']},
#  {'orcid-id': '0000-0003-0659-7875',
#   'given-names': 'Red',
#   'family-names': 'Phantom',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Aries Systems Corporation']},
#  {'orcid-id': '0000-0003-0880-7469',
#   'given-names': 'firstxyz',
#   'family-names': 'lastxyz',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Royal Society of New Zealand',
#    'The University of Auckland']},
#  {'orcid-id': '0000-0003-2193-4075',
#   'given-names': 'Aleš',
#   'family-names': 'Haladej',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['VSB - Technical University of Ostrava']},
#  {'orcid-id': '0000-0002-2389-8429',
#   'given-names': 'Sofia',
#   'family-names': 'Hernandez',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-0621-8532',
#   'given-names': 'Patrick',
#   'family-names': 'Ruan',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Aalto University',
#    'Apple',
#    'Harvard',
#    'IIT',
#    'Institute of Electron Technology',
#    'Madurai Kamaraj University',
#    'Nortel (Canada)',
#    'Pontifical Catholic University of Rio de Janeiro',
#    'Pratt',
#    'Public Power Corporation (Greece)',
#    'RWTH Aachen University',
#    'Sana Biotechnology (United States)',
#    'Springfield',
#    'TU Dresden',
#    'Teck (Canada)',
#    'Trojan Technologies (Canada)',
#    'UIC College Prep',
#    'UIUC',
#    'UNSW Sydney',
#    'University Medical Center Groningen',
#    'University of Delhi',
#    'University of Hyderabad',
#    'University of Las Palmas de Gran Canaria',
#    'University of Melbourne',
#    'University of Pune',
#    'University of Queensland',
#    'University of Turku',
#    'Warsaw University of Technology',
#    'Wrocław Medical University',
#    'beatles',
#    'dog',
#    'grass',
#    'llinois State University Department of Health Sciences',
#    'marquetter',
#    'me',
#    'normal',
#    'psychic',
#    'something',
#    'ukes']},
#  {'orcid-id': '0000-0002-5905-6370',
#   'given-names': 'Aleš',
#   'family-names': 'Haladej',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['VSB - Technical University of Ostrava']},
#  {'orcid-id': '0000-0002-9622-9090',
#   'given-names': 'Chris',
#   'family-names': 'Andrews',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Canterbury']},
#  {'orcid-id': '0000-0002-8737-3672',
#   'given-names': 'testing',
#   'family-names': '27/9',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Zarqa University',
#    'cellXica ltd',
#    'crossref ID',
#    'eCow Devon (United Kingdom)',
#    'grid ID test',
#    'haystack NV',
#    'new 27/9',
#    'ringgold test ID',
#    'write to ORCID']},
#  {'orcid-id': '0000-0002-7956-1059',
#   'given-names': 'Blue',
#   'family-names': 'Phantom',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Aries Systems Corporation',
#    'University of New Hampshire',
#    'University of North Texas College of Education']},
#  {'orcid-id': '0000-0002-2590-8280',
#   'given-names': 'Sukanya',
#   'family-names': 'Vejella',
#   'credit-name': None,
#   'other-name': [],
#   'email': ['sukanya@mailinator.com'],
#   'institution-name': ['ORCID', 'University of South Australia']},
#  {'orcid-id': '0000-0002-0859-6764',
#   'given-names': 'Emre',
#   'family-names': 'd',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-4621-1191',
#   'given-names': 'test',
#   'family-names': 'bmj',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['BMJ Publishing Group']},
#  {'orcid-id': '0000-0001-6831-790X',
#   'given-names': 'Roshan',
#   'family-names': 'Paward',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['The University of Auckland']},
#  {'orcid-id': '0000-0003-4445-6520',
#   'given-names': 'Cameron',
#   'family-names': 'Stanton',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Royal Society Te Ap?rangi',
#    'Royal Society Te Apārangi',
#    'St John',
#    'Victoria University of Wellington']},
#  {'orcid-id': '0000-0001-7982-4165',
#   'given-names': 'deepak',
#   'family-names': 'batham',
#   'credit-name': None,
#   'other-name': [],
#   'email': ['Deepak.batham@mailinator.com'],
#   'institution-name': ['Aptara', 'Aptara Corporation India']},
#  {'orcid-id': '0000-0003-3336-9341',
#   'given-names': 'Rod',
#   'family-names': 'Lewis',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Australian Catholic University']},
#  {'orcid-id': '0000-0001-5037-1836',
#   'given-names': 'omar',
#   'family-names': 'Alnsoor',
#   'credit-name': None,
#   'other-name': ['cxcxcxcx', 'fdgdfgdf', '44   444', '44- 444'],
#   'email': ['omarnsoor3@mailinator.com', 'omarnsoor13@mailinator.com'],
#   'institution-name': ['Al Balqa Applied University12',
#    'Universitetska mnogoprofilna bolnica za aktivno lecenie i spesna medicina Nikolaj Ivanovic Pirogov EAD',
#    'XZY Maps Ltd',
#    'alphaXRT Pty Ltd',
#    'ewp Holding AG',
#    'gisunt Klinik',
#    'groupH Ltd']},
#  {'orcid-id': '0000-0001-9828-546X',
#   'given-names': 'steve',
#   'family-names': 'gu',
#   'credit-name': 'Weigang Gu',
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Emory University',
#    'Massachusetts Institute of Technology',
#    'Northrop Grumman']},
#  {'orcid-id': '0000-0002-0888-7393',
#   'given-names': 'Roshan',
#   'family-names': 'Pawar',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['CRL Energy Ltd']},
#  {'orcid-id': '0000-0002-9618-120X',
#   'given-names': 'newuser',
#   'family-names': 'newlastname',
#   'credit-name': None,
#   'other-name': ['dummy 1220spp'],
#   'email': [],
#   'institution-name': ['The University of Auckland']},
#  {'orcid-id': '0000-0001-9357-7498',
#   'given-names': 'Generic',
#   'family-names': 'Contributor2',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['The Test NZ ORCID Hub']},
#  {'orcid-id': '0000-0003-0211-5429',
#   'given-names': 'Lev',
#   'family-names': 'Guzeev',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0003-2923-0785',
#   'given-names': 'Roshan',
#   'family-names': 'Pawars',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Institute of Geological & Nuclear Sciences Ltd']},
#  {'orcid-id': '0000-0002-3695-8291',
#   'given-names': 'Kok Wai',
#   'family-names': 'BUStaff',
#   'credit-name': 'Kok Wai Cheah',
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Hong Kong Baptist University']},
#  {'orcid-id': '0000-0002-6530-553X',
#   'given-names': 'Kok Wai',
#   'family-names': 'BUStaff',
#   'credit-name': 'Kok Wai Cheah',
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Hong Kong Baptist University']},
#  {'orcid-id': '0000-0002-4955-8190',
#   'given-names': 'Laura',
#   'family-names': 'Paglione',
#   'credit-name': 'Laura AD Paglione',
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0001-5937-8807',
#   'given-names': 'Survey',
#   'family-names': 'Test',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Wisconsin-Madison']},
#  {'orcid-id': '0000-0002-7789-6031',
#   'given-names': 'QA',
#   'family-names': '27/9',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['grid ID test', 'new 27/9', 'write to ORCID']},
#  {'orcid-id': '0000-0002-7199-110X',
#   'given-names': 'Lawrence',
#   'family-names': 'Chaney',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Royal Society Te Apārangi']},
#  {'orcid-id': '0000-0003-4829-5613',
#   'given-names': 'marley',
#   'family-names': 'zhu',
#   'credit-name': None,
#   'other-name': [],
#   'email': ['marley_zhu@mailinator.com', 'm_zhu@acs.org'],
#   'institution-name': ['American Chemical Society',
#    'American College of Chest Physicians',
#    'American Physical Society']},
#  {'orcid-id': '0000-0002-7730-8391',
#   'given-names': 'newuser',
#   'family-names': 'newlastname',
#   'credit-name': None,
#   'other-name': ['dummy 1220swe'],
#   'email': [],
#   'institution-name': ['The University of Auckland']},
#  {'orcid-id': '0000-0002-2717-1382',
#   'given-names': 'Nora',
#   'family-names': 'Daly',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Sloan Kettering Institute']},
#  {'orcid-id': '0000-0001-5533-5375',
#   'given-names': 'Adit',
#   'family-names': 'Lakhani',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University College London']},
#  {'orcid-id': '0000-0001-7897-8840',
#   'given-names': 'Shaq',
#   'family-names': 'Oneal',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-5080-212X',
#   'given-names': 'newuser',
#   'family-names': 'newlastname',
#   'credit-name': None,
#   'other-name': ['dummy 1220s', 'https://fdhfdasa112j.com'],
#   'email': [],
#   'institution-name': ['The University of Auckland']},
#  {'orcid-id': '0000-0003-3240-7211',
#   'given-names': 'Demo',
#   'family-names': 'Account',
#   'credit-name': None,
#   'other-name': ['Alternative Name 1',
#    'Alternative Name 3',
#    'Alternative Name 4',
#    'Alternative Name 5',
#    'Alternative Name 6'],
#   'email': [],
#   'institution-name': ['Amman Arab University - Administration Office',
#    'JAVNA Wireless Software Solutions co.']},
#  {'orcid-id': '0000-0003-1654-9658',
#   'given-names': 'AISWARYA!',
#   'family-names': 'LIVE!',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['19th Force Support Squadron',
#    'American College Testing',
#    'Boston University School of Public Health',
#    'British Council Qatar',
#    'Christ the King Seminary',
#    'Education/degree from ORCHID',
#    'Friends For an Earlier Breast Cancer Test',
#    'German Historical Institute',
#    'HTC Corp',
#    'Jisc',
#    'Kilpailu- ja kuluttajavirasto',
#    'King Abdullah University of Science and Technology',
#    'Massachusetts Institute of Technology',
#    'McGinnis Lochridge and Kilgore LLP',
#    'Ministry of Higher Education, Malaysia',
#    'National Cheng Kung University',
#    'National Lighting Test Center',
#    'New Inst11',
#    'Royal Society of New Zealand',
#    'Shipman and Goodwin LLP',
#    'Sloan-Kettering Institute',
#    'Test Consortium',
#    'Test Education Ltd',
#    'Test Parent',
#    'Universitatea de Stat de Medicina si Farmacie Nicolae Testemitanu',
#    'University of Colorado Boulder',
#    'University of Manchester']},
#  {'orcid-id': '0000-0002-2945-4220',
#   'given-names': 'Rose',
#   'family-names': 'Reviewer',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0001-8491-7374',
#   'given-names': 'Bryan',
#   'family-names': 'Neff',
#   'credit-name': None,
#   'other-name': [],
#   'email': ['aries.test.vijay@mailinator.com', 'v@mailinator.com'],
#   'institution-name': ['Lincoln University',
#    'Pennsylvania State University',
#    'Pennsylvania State University College of Engineering']},
#  {'orcid-id': '0000-0002-3346-4528',
#   'given-names': 'Tom2',
#   'family-names': 'Hopkins',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0001-8652-3619',
#   'given-names': 'pc',
#   'family-names': 'person',
#   'credit-name': None,
#   'other-name': [],
#   'email': ['aiswaryanew@mailinator.com',
#    'pcperson@mailinator.com',
#    'aiswaryanew3@mailinator.com',
#    'aiswaryanew1@mailinator.com',
#    'aiswaryanew333@mailinator.com',
#    'aiswaryanew33@mailinator.com'],
#   'institution-name': ['19th Force Support Squadron',
#    'American Management Systems Inc',
#    'American Society for Nondestructive Testing',
#    'American Society for Nondestructive Testing!',
#    'Cancer Services of New Mexico',
#    'Central Institute for Subtropical Horticulture',
#    'Fred Hutchinson Cancer Research Center 222',
#    'Friends For an Earlier Breast Cancer Test',
#    'Harcourt Test Publishers',
#    'Hospital Sultan Ismail',
#    'Kilian Community College',
#    "King's College London",
#    'Massachusetts Institute of Technology',
#    'New York City Bar Association',
#    'Sloan-Kettering Institute',
#    'Sultan Qaboos University',
#    'Test Consortium',
#    'Test Consortium new#',
#    'Test new',
#    'Testaverde Fund for Spinal Cord Injury',
#    'University of London',
#    'University of New England',
#    'Van Leer Jerusalem Institute 1',
#    'iuiouiouo',
#    'kjkjkjk',
#    'tyryrtyrtyrty1',
#    'yututyutyut']},
#  {'orcid-id': '0000-0002-9527-7621',
#   'given-names': 'Aleksandr',
#   'family-names': 'Kotin',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': []},
#  {'orcid-id': '0000-0002-7062-4463',
#   'given-names': 'QA',
#   'family-names': 'SmartSimple',
#   'credit-name': None,
#   'other-name': ['QA AKA'],
#   'email': [],
#   'institution-name': ['Area Education Agency 267',
#    'Belfast Public Library',
#    'Loreto Grammar School',
#    'Mellon Centre for Migration Studies',
#    'Northern Ireland Centre for Trauma and Transformation',
#    'Omagh Academy',
#    'Omagh District Council',
#    'Strabane Library',
#    'Toronto East General Hospital Foundation',
#    'University of Liverpool',
#    'University of Oxford',
#    'University of Queensland']},
#  {'orcid-id': '0000-0003-4640-277X',
#   'given-names': 'Debbie',
#   'family-names': 'Woodhasllss',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Royal Society Te Apārangi']},
#  {'orcid-id': '0000-0002-7104-5260',
#   'given-names': 'asasa',
#   'family-names': 'asasasa',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Royal Society Te Apārangi']},
#  {'orcid-id': '0000-0003-3936-2618',
#   'given-names': 'Clarence',
#   'family-names': 'Goodman',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Massey University']},
#  {'orcid-id': '0000-0001-8483-4069',
#   'given-names': 'Debbie',
#   'family-names': 'Woodhallss',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Institute of Geological & Nuclear Sciences Ltd',
#    'The University of Auckland']},
#  {'orcid-id': '0000-0002-4958-8146',
#   'given-names': 'Colleen',
#   'family-names': 'Feng',
#   'credit-name': None,
# ...
#  {'orcid-id': '0000-0001-5955-5703',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-5427-6761',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-0912-7871',
#   'given-names': 'J',
#   'family-names': 'J',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0001-9964-6888',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0003-0064-0414',
#   'given-names': 'An-Kuo',
#   'family-names': 'Li',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-0768-4973',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-7526-4233',
#   'given-names': 'Yi-Hung',
#   'family-names': 'Chiou',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-8713-4946',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-7463-2698',
#   'given-names': 'Yi-Hung',
#   'family-names': 'Chiou',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0003-1079-2497',
#   'given-names': None,
#   'family-names': None,
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Universidad de Zaragoza']},
#  {'orcid-id': '0000-0002-9002-7818',
#   'given-names': None,
#   'family-names': None,
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Universidad de Zaragoza']},
#  {'orcid-id': '0000-0001-7494-6446',
#   'given-names': None,
#   'family-names': None,
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Universidad de Zaragoza']},
#  {'orcid-id': '0000-0003-4710-9006',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-8577-8350',
#   'given-names': 'Yong-Han',
#   'family-names': 'Lin',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-0875-9586',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-2832-5486',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-3251-8600',
#   'given-names': 'Yukinori',
#   'family-names': 'Okada',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ["Brigham and Women's Hospital"]},
#  {'orcid-id': '0000-0002-9769-1789',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0001-5576-3492',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0001-6168-7625',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-9200-090X',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-0770-2836',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0003-4180-2029',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-6029-3920',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-5737-9328',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0001-9636-9205',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-3074-5391',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-5317-187X',
#   'given-names': 'Yi-Hung',
#   'family-names': 'Chiou',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-8745-8617',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0003-0340-4185',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0001-6700-1508',
#   'given-names': 'Yi-Hung',
#   'family-names': 'Chiou',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0001-7944-0233',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0003-2971-5352',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-6624-3406',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-3824-2115',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0003-2377-8838',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0001-6319-4381',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-4085-5666',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-4091-729X',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-5806-0490',
#   'given-names': 'J',
#   'family-names': 'J',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-0422-2765',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-7128-5483',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-6281-649X',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-2950-665X',
#   'given-names': 'Shan',
#   'family-names': 'Zeng',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['Sloan Kettering Institute']},
#  {'orcid-id': '0000-0002-7947-9186',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-4349-1271',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0001-6742-0219',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0001-8520-5328',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-6693-5453',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-2045-2165',
#   'given-names': 'Yong-Han',
#   'family-names': 'Lin',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-8078-4583',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-5633-6406',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-0875-3555',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-8076-5358',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0003-4606-9321',
#   'given-names': 'Jenny',
#   'family-names': 'Chen',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0003-2986-7567',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0001-6843-3820',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-7793-5168',
#   'given-names': 'J',
#   'family-names': 'J',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-5235-3188',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-4827-0769',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0003-1346-4288',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-1653-6155',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0001-6423-9166',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-3542-0932',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0003-4238-0008',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0001-7564-4757',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0001-8998-0487',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0003-1984-8012',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0001-6091-6182',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0002-1906-5985',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0001-9116-5393',
#   'given-names': 'Albert',
#   'family-names': 'Einstein',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['National Chiao Tung University']},
#  {'orcid-id': '0000-0001-8454-1397',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-0548-4046',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-2275-0115',
#   'given-names': 'MARY',
#   'family-names': 'NELSON',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0001-6001-1615',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0002-6616-1929',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  {'orcid-id': '0000-0001-8213-697X',
#   'given-names': 'TOM',
#   'family-names': 'HOBBINS',
#   'credit-name': None,
#   'other-name': [],
#   'email': [],
#   'institution-name': ['University of Colorado Boulder']},
#  ...]

# %%
print(len(search_response_list))
print(type(search_response_list))
print(search_response_list[1])
print(type(search_response_list[1]))
# Out:
# 36399
# <class 'list'>
# {'orcid-id': '0000-0002-3270-2838', 'given-names': 'Priya', 'family-names': 'Joshi', 'credit-name': None, 'other-name': [], 'email': ['priya.joshi454@bmc.org', 'pjoshi454@bu.edu'], 'institution-name': []}
# <class 'dict'>

# %%
## Step 3: Convert response, which isa list of dictionaries into pandas dataframe

orcid_results_df = pd.json_normalize(search_response_list, record_path=["expanded-result"])
orcid_results_df.head()

# %%
# Out:
# <class 'str'>
# <class 'dict'>
#               orcid-id given-names family-names credit-name other-name  \
# 0  0000-0002-0564-3270     ALIREZA      DOOSTAN        None         []
# 1  0000-0002-3270-2838       Priya        Joshi        None         []
# 2  0000-0001-9962-7513  Researcher         Test        None         []
# 3  0000-0002-3270-5131        Carl       O'Hara        None         []
# 4  0000-0002-3270-2950      Albert     Einstein        None         []
#
#                                         email  \
# 0                                          []
# 1  [priya.joshi454@bmc.org, pjoshi454@bu.edu]
# 2                                          []
# 3                            [hara461@bu.edu]
# 4                                          []
#
#                                     institution-name
# 0                   [University of Colorado Boulder]
# 1                                                 []
# 2  [Mc Gill University, My College, My University...
# 3                                                 []
# 4                                                 []

# %%
## Step 4: Save dataframe to a CSV

with open(r"orcid_results_df.csv", 'w', encoding='utf-8') as file:
    orcid_results_df.to_csv(file, line_terminator='\n', index=True)
    file.close()

# %% [markdown]
# ## Pathway for editing an ORCID record using the ORCID Member API
#
# ### Pathway code note yet complete
#
# Note, this pathway is similar to if a user were to give permission to Scopus to update their record. So it doesn't really translate well into a Jupyter Notebook becuase we're not a web application asking a user to give us permission. More so, this pathway is included here so you can see how it works.

# %%
## Step 1: Authenticate with ORCID to receive a token

## https://info.orcid.org/documentation/integration-guide/getting-started-with-your-orcid-integration/#easy-faq-2569

## Set up URL and parameters
url = "https://sandbox.orcid.org/oauth/authorize?"

parameters = {
    "client_id": ClientID,
    "client_secret": Clientsecret,
    "response_type" : "code",
    "scope": "read-limited",
    "redirect_uri" : "https://api.sandbox.orcid.org"
    
}

             
## Make the API request 

response = requests.get(url, params = parameters) #headers = headers,

## Print responses
print(response.status_code)
print(response.url)
# print(response.text)

## Click on the URL and authenticate with your sandbox ORCID username and password. 
## Don't yet have sandbox ORCID username and password? 
## username must be: XXXXX@mailinator.com
## Need to reset your sandbox ORCID password?
## You can go to https://www.mailinator.com/ and enter your username in the textbox 
## This will take you to your public mailbox and where youwill find the password reset email

## Resources
## https://info.orcid.org/faq/how-does-3-legged-oauth-work/

# %%
## Step 2: Exchange the code received for a token. 
## The code expires upon use but the token is good for multiple uses and expires after 20 years

URL=https://sandbox.orcid.org/oauth/token
  HEADER: Accept: application/json
  HEADER: Content-Type: application/x-www-form-urlencoded
  METHOD: POST
  DATA: 
    client_id=[Your client ID]
    client_secret=[Your client secret]
    grant_type=authorization_code
    code=Six-digit code
    redirect_uri=[Your landing page]
    
## Resources
## https://info.orcid.org/faq/how-does-3-legged-oauth-work/

# %%
## Step 3: Use the token in API requests you make to read or update that record.

# %%
# https://pub.sandbox.orcid.org/v3.0/search/?q=family-name:Einstein+AND+keyword:Relativity&start=0&rows=10
#             https://pub.sandbox.orcid.org/v3.0/search/?q=email:*@orcid.org

# Sandbox: https://api.sandbox.orcid.org

# Production: https://api.orcid.org

# Method: GET
#   Content-type: text/csv
#   Authorization type: Bearer
#   Access token: [Stored access token]
#   URL:  https://api.orcid.org/v3.0/csv-search/?q=ringgold-org-id:385488&fl=orcid,given-names,family-name,current-institution-affiliation-name,'
